# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in ./.local/lib/python3.12/site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U --user pandas ollama
# Out:
# Requirement already satisfied: pandas in ./.local/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: ollama in ./.local/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib64/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/site-packages (from ollama) (2.11.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/site-packages (from httpx>=0.27->ollama) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib64/python3.12/site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)

# %%
import os
import json
import ollama
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# %%
FRAMES_DIR = "frames"
MODEL_FILE = "model.csv"

# %%
image_files = [
    os.path.join(FRAMES_DIR, f)
    for f in os.listdir(FRAMES_DIR)
    if f.lower().endswith((".jpg", ".jpeg", ".png", ".webp", ".bmp"))
]

print("Found", len(image_files), "image(s)")
print(image_files[:10])
# Out:
# Found 182 image(s)
# ['frames/frame_0028.jpg', 'frames/frame_0162.jpg', 'frames/frame_0128.jpg', 'frames/frame_0151.jpg', 'frames/frame_0004.jpg', 'frames/frame_0076.jpg', 'frames/frame_0071.jpg', 'frames/frame_0032.jpg', 'frames/frame_0146.jpg', 'frames/frame_0026.jpg']

# %%
def describe_image(image_path, model_name="ministral-3:3b"):
    response = ollama.chat(
        model=model_name,
        messages=[
            {
                "role": "user",
                "content": "Describe this animal image briefly in one sentence for image search.",
                "images": [image_path],
            }
        ],
    )
    return response["message"]["content"]

# %%
def get_embedding(text, model_name="embeddinggemma"):
    response = ollama.embeddings(
        model=model_name,
        prompt=text
    )
    return np.array(response["embedding"], dtype=np.float32)

# %%
def make_model_df():
    return pd.DataFrame(columns=["filename", "description", "embedding"])

# %%
def add_image_to_model(model_df, image_path, vision_model="ministral-3:3b", embedding_model="embeddinggemma"):
    description = describe_image(image_path, model_name=vision_model)
    embedding = get_embedding(description, model_name=embedding_model)

    new_row = pd.DataFrame([{
        "filename": image_path,
        "description": description,
        "embedding": embedding
    }])

    return pd.concat([model_df, new_row], ignore_index=True)

# %%
def find_most_similar(model_df, query_embedding):
    all_embeddings = np.vstack(model_df["embedding"].values)
    sims = cosine_similarity([query_embedding], all_embeddings)[0]
    best_idx = int(np.argmax(sims))
    return model_df.iloc[best_idx][["filename", "description"]], sims[best_idx]

# %%
def save_model_csv(model_df, path):
    df = model_df.copy()
    df["embedding"] = df["embedding"].apply(lambda x: json.dumps(x.tolist()))
    df.to_csv(path, index=False)

def load_model_csv(path):
    df = pd.read_csv(path)
    df["embedding"] = df["embedding"].apply(lambda x: np.array(json.loads(x), dtype=np.float32))
    return df

# %%
test_text = "Show me a bear"
emb = get_embedding(test_text)

print(type(emb))
print(emb.shape)
# Out:
# <class 'numpy.ndarray'>
# (768,)

# %%
model = make_model_df()

sample_images = image_files[:3]
print("Using these images:")
for img in sample_images:
    print("-", img)
# Out:
# Using these images:
# - frames/frame_0028.jpg
# - frames/frame_0162.jpg
# - frames/frame_0128.jpg

# %%
for img_path in sample_images:
    model = add_image_to_model(model, img_path)

model[["filename", "description"]]
# Out:
#                 filename                                        description
# 0  frames/frame_0028.jpg  A close-up of a kangaroo sitting among green f...
# 1  frames/frame_0162.jpg  This image shows a close-up of a **Gila monste...
# 2  frames/frame_0128.jpg  A pink flamingo standing gracefully in shallow...

# %%
save_model_csv(model, MODEL_FILE)
print("Saved model to", MODEL_FILE)
# Out:
# Saved model to model.csv

# %%
loaded_model = load_model_csv(MODEL_FILE)
loaded_model[["filename", "description"]]
# Out:
#                 filename                                        description
# 0  frames/frame_0028.jpg  A close-up of a kangaroo sitting among green f...
# 1  frames/frame_0162.jpg  This image shows a close-up of a **Gila monste...
# 2  frames/frame_0128.jpg  A pink flamingo standing gracefully in shallow...

# %%
query = "Show me a kangaroo"
query_embedding = get_embedding(query)

result, score = find_most_similar(loaded_model, query_embedding)

print("Query:", query)
print("Best match:", result["filename"])
print("Description:", result["description"])
print("Similarity score:", score)
# Out:
# Query: Show me a kangaroo
# Best match: frames/frame_0028.jpg
# Description: A close-up of a kangaroo sitting among green foliage with purple wildflowers in the background.
# Similarity score: 0.540275

# %%
img = Image.open(result["filename"])

plt.figure(figsize=(6, 6))
plt.imshow(img)
plt.axis("off")
plt.title(result["description"])
plt.show()
